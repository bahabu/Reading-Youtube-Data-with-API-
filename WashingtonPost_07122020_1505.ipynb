# %%
api_key = "AIzaSyBNUj7PYvALgJjyauXCnc420wYMwvMBThk"
username= "WashingtonPost"

# %%
import urllib
import urllib.request
import json
import csv
import re
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as stat

# %%
url = f"https://www.googleapis.com/youtube/v3/channels?key={api_key}&forUsername={username}&part=id"
json_url = urllib.request.urlopen(url)
channel_data = json.loads(json_url.read())
channel_data
# Out:
# {'etag': 'T4iOyj-MnzqUR1feT8JhxETuiAg',
#  'items': [{'etag': 'osO_iHJQO80T6kFiUv9WdJ24zGo',
#    'id': 'UCHd62-u_v4DvJ8TCFtpi4GA',
#    'kind': 'youtube#channel'}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 5, 'totalResults': 1}}

# %%
channel_id = "UCHd62-u_v4DvJ8TCFtpi4GA"

# %%
url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&channelId={channel_id}&part=snippet,id&order=date&maxResults=99"
json_url = urllib.request.urlopen(url)
videodata= json.loads(json_url.read())
videodata
# Out:
# {'etag': 'cFQA6iXQ9zw9rUoH_yUQzWHZcco',
#  'items': [{'etag': 'UoaTKOoXM1yL--C2fNVI0qOV4os',
#    'id': {'kind': 'youtube#video', 'videoId': '1mrjfNh3Xuw'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCHd62-u_v4DvJ8TCFtpi4GA',
#     'channelTitle': 'Washington Post',
#     'description': 'As coronavirus cases surged, Democratic politicians enacted guidelines to slow the spread of the virus. But at times, those same politicians ignored their own ...',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-12-07T22:52:53Z',
#     'publishedAt': '2020-12-07T22:52:53Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/1mrjfNh3Xuw/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/1mrjfNh3Xuw/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/1mrjfNh3Xuw/mqdefault.jpg',
#       'width': 320}},
# ...

# %%
video_ids_auto = ""
for i in range(len(videodata['items'])):
    a = videodata["items"][i]["id"]['videoId']
    video_ids_auto += a+"," 
video_ids_auto = video_ids_auto[:-1]

video_ids_auto
# Out:
# '1mrjfNh3Xuw,FAna3YZ4Bhg,y3QvbcoCtr0,zfbMpUpVyKE,jF3WtrPDmHU,fZT1b2Mqx40,5PbjE1HkF7c,XxwmlzISkFI,flB4YY8ORI8,cxA2PyUmBOk,hx_B-f1DugE,ZPHQrpwnEbo,cMKvBU_cgnU,ddKfB3uaWYQ,Up-CGG9fmKw,Cl7TZq8Qx3Q,t65dmXZfAC8,ATp2MCQdPdM,Gs5Jy4Yeo3I,MPHJaCjGUUw,kQrDpIDUMUs,W-CW8tFaEsM,mjeUoVOoTGM,1iHKG3Giryc,HD9W5wn4zb8,eXYg0AT4hJY,9DCjp0l3z-0,OkK50ibO2iA,J-qNaiAkxUM,QaOPtGzvax8,Ksml601G2i4,qghXaGWINA8,rhcZEoZmFuw,bTPSG1XeAWg,HyAyrsaA-_U,R698Xm2iwhQ,LBM9Ke_JI1Q,4ytsirmDIXs,kiVPWPAR4m0,2s5Y_6WDRqY,KdWg2htgFaY,aCFb71gckqU,_xBm2SMTQj4,OP55rFXjWxE,H5tN19p7HII,Mz71lY66Hs8,zui-a4RWESw,RwkEpi-1MMU,wvB9A7isoZI,iuKyAbq60_4'

# %%
url = f"https://www.googleapis.com/youtube/v3/videos?part=snippet,contentDetails,statistics&id={video_ids_auto}&key={api_key}"
json_url = urllib.request.urlopen(url)
video_stats_data = json.loads(json_url.read())
video_stats_data
# Out:
# {'etag': '5WqvBhiWjJTOVNZ6HJNU4q5gv8I',
#  'items': [{'contentDetails': {'caption': 'false',
#     'contentRating': {},
#     'definition': 'hd',
#     'dimension': '2d',
#     'duration': 'PT1M37S',
#     'licensedContent': True,
#     'projection': 'rectangular'},
#    'etag': 'D4CfhdYgdaf5y97Pz7CH_4KT0wo',
#    'id': '1mrjfNh3Xuw',
#    'kind': 'youtube#video',
#    'snippet': {'categoryId': '25',
#     'channelId': 'UCHd62-u_v4DvJ8TCFtpi4GA',
#     'channelTitle': 'Washington Post',
#     'description': 'As coronavirus cases surged, Democratic politicians enacted guidelines to slow the spread of the virus. But at times, those same politicians ignored their own guidance. Read more: https://wapo.st/2VQwoIY. Subscribe to The Washington Post on YouTube: https://wapo.st/2QOdcqK\n\nFollow us:\nTwitter: https://twitter.com/washingtonpost\nInstagram: https://www.instagram.com/washingtonpost/\nFacebook: https://www.facebook.com/washingtonpost/',
#     'liveBroadcastContent': 'none',
# ...

# %%
item = []
for i in range(len(video_stats_data['items'])):
    a = video_stats_data["items"][i]["statistics"]
    item.append(a)
print(item)
# Out:
# [{'viewCount': '535', 'likeCount': '15', 'dislikeCount': '2', 'favoriteCount': '0', 'commentCount': '12'}, {'viewCount': '3002', 'likeCount': '107', 'dislikeCount': '26', 'favoriteCount': '0'}, {'viewCount': '4993', 'likeCount': '106', 'dislikeCount': '63', 'favoriteCount': '0'}, {'viewCount': '216119', 'likeCount': '1783', 'dislikeCount': '618', 'favoriteCount': '0', 'commentCount': '2110'}, {'viewCount': '454825', 'likeCount': '4950', 'dislikeCount': '3779', 'favoriteCount': '0', 'commentCount': '3199'}, {'viewCount': '450400', 'likeCount': '4446', 'dislikeCount': '6635', 'favoriteCount': '0', 'commentCount': '9759'}, {'viewCount': '31048', 'likeCount': '242', 'dislikeCount': '79', 'favoriteCount': '0', 'commentCount': '417'}, {'viewCount': '106714', 'likeCount': '1285', 'dislikeCount': '1255', 'favoriteCount': '0', 'commentCount': '982'}, {'viewCount': '12274', 'likeCount': '153', 'dislikeCount': '146', 'favoriteCount': '0', 'commentCount': '355'}, {'viewCount': '4339', 'likeCount
# ...

# %%
fields = ["viewCount", "likeCount", "dislikeCount", "favoriteCount", "commentCount"]
with open("youtuberstat.csv", "w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames = fields)
    writer.writeheader() 
    writer.writerows(item)

# %%
df = pd.read_csv("youtuberstat.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   viewCount      50 non-null     int64
#  1   likeCount      50 non-null     int64
#  2   dislikeCount   50 non-null     int64
#  3   favoriteCount  50 non-null     int64
#  4   commentCount   31 non-null     float64
# dtypes: float64(1), int64(4)
# memory usage:
# 22    2020-12-02T00:36:37Z
# 23    2020-12-01T23:26:14Z
# 24    2020-12-01T20:59:49Z
# 25    2020-12-01T19:01:44Z
# 26    2020-12-01T16:11:23Z
# 27    2020-12-01T15:22:54Z
# 28    2020-11-30T21:45:37Z
# 29    2020-11-29T22:06:39Z
# 30    2020-11-29T19:24:07Z
# 31    2020-11-28T19:45:43Z
# 32    2020-11-23T17:39:05Z
# 33    2020-11-22T19:29:06Z
# ...

# %%
add_list = []
def add_col(add):
    for i in range(50):
        b = video_stats_data["items"][i]["snippet"][add]
        add_list.append(b)
    return add_list

# %%
add_col("title")
df["title"] = add_list
df.head()
# Out:
#    viewCount  ...                                              title
# 0        535  ...  Democrats ignore their own coronavirus guidanc...
# 1       3002  ...  Retired Lt. Gen. Paul Ostrowski on Operation W...
# 2       4993  ...  White House chief economic adviser Larry Kudlo...
# 3     216119  ...  Giuliani spent the week crisscrossing the coun...
# 4     454825  ...  SNL Recap | Rudy Giuliani, Melissa Carone and ...
#
# [5 rows x 7 columns]

# %%
plt.subplots(figsize=(10, 5))
plt.xticks(rotation=90)
sns.barplot(y=df["likeCount"], x=df["title"], data=df)

# %%
plt.subplots(figsize=(10, 5))
plt.xticks(rotation=90)
sns.barplot(y=df["dislikeCount"], x=df["title"], data=df)

# %%
df_corona = df[df['title'].str.contains("corona")]
df_corona
# Out:
#     viewCount  ...                                              title
# 0         535  ...  Democrats ignore their own coronavirus guidanc...
# 3      216119  ...  Giuliani spent the week crisscrossing the coun...
# 10       3927  ...  Pelosi defends smaller coronavirus relief bill...
# 11      17616  ...  Pelosi holds weekly news conference amid coron...
# 15       1608  ...  Contact tracer in North Dakota shares difficul...
# 23       4351  ...  WATCH: CDC advisers vote on who will be first ...
# 26       4975  ...  WATCH: Bipartisan Senator group expected to un...
# 28          0  ...  WATCH LIVE: Chief science adviser to Operation...
# 41      86207  ...  Pelosi urges 'separation,' other measures to s...
# 42     349292  ...  WATCH: Trump delivers remarks on coronavirus v...
# 45      94990  ...  WATCH: Maryland Gov. Hogan holds news conferen...
#
# [11 rows x 7 columns]

# %%
plt.subplots(figsize=(10, 5))
plt.xticks(rotation=90)
sns.barplot(y=df_corona["likeCount"], x=df_corona["title"], data=df_corona)

# %%
plt.subplots(figsize=(10, 5))
plt.xticks(rotation=90)
sns.barplot(y=df_corona["dislikeCount"], x=df_corona["title"], data=df_corona)

# %%
plt.subplots(figsize=(10, 5))
plt.xticks(rotation=90)
sns.barplot(y=df_corona["viewCount"], x=df_corona["title"], data=df_corona)

# %%
dislike_mean_corona = stat.mean(df_corona["dislikeCount"])
like_mean_corona = stat.mean(df_corona["likeCount"])
rating_mean_corona = like_mean_corona/dislike_mean_corona

dislike_mean = stat.mean(df["dislikeCount"])
like_mean = stat.mean(df["likeCount"])
rating_mean = like_mean/dislike_mean

# %%
df_corona_plot = pd.DataFrame({
    'Factor': ['Non-corona','Corona'],
    'rating_mean': [rating_mean, rating_mean_corona]
})
tidy = df_corona_plot.melt(id_vars='Factor').rename(columns=str.title)

# %%
fig, ax1 = plt.subplots(figsize=(10,5))
sns.barplot(x='Factor', y='Value', data=tidy, ax=ax1).set(ylabel='Like/dislike ratio',xlabel='')
sns.despine(fig)
